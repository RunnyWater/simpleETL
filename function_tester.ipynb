# %%
# %run tests.ipynb

# %%
df = get_data('youtube_example_db.csv')

# %%
df_fill_na = fill_na_knn(df, 'numeric-mean')
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_fill_na = fill_na_knn(df, 'numeric-mean')
#
# File ~\AppData\Local\Temp\ipykernel_8472\2148505808.py:26, in fill_na_knn(df, n_neighbors)
#      24 df = df.copy().select_dtypes(include=['int64', 'float64'])
#      25 imputer = KNNImputer(n_neighbors=n_neighbors)
# ---> 26 df_array = imputer.fit_transform(df)
#      27 df_imputed = pd.DataFrame(df_array, index=df.index, columns=df.columns)
#      28 return df_imputed
#
# File g:\Desktop\simpleETL\venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
# ...

# %%
df_fill_na
# Out:
#      subscribers   total_views  total_videos
# 0     16600000.0  9.092244e+09        6989.0
# 1      1516400.0  2.575985e+08         243.0
# 2      4010000.0  8.709679e+08        1897.0
# 3      2990000.0  1.786093e+08        1000.0
# 4      2080000.0  8.212029e+07        1740.0
# ..           ...           ...           ...
# 125      11400.0  3.021380e+05        1138.0
# 126      11200.0  6.878757e+06         212.0
# 127      11000.0  1.303810e+05          60.0
# 128      10900.0  5.874990e+05          64.0
# 129      10800.0  8.393310e+05          35.0
#
# [130 rows x 3 columns]

# %%
save_data(df_fill_na, 'df_fill_na_test')
